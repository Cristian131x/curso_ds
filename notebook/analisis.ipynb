# %%
# Comentario nuevo
import pandas as pd
df = pd.read_csv("../data/clientes.csv")
df
# Out:
#    id_cliente          nombre  edad        ciudad                    correo
# 0           1      Juan Pérez    25      Santiago      juan.perez@email.com
# 1           2  María González    30    Valparaíso  maria.gonzalez@email.com
# 2           3    Carlos López    22    Concepción    carlos.lopez@email.com
# 3           4    Ana Martínez    28     La Serena    ana.martinez@email.com
# 4           5      Pedro Díaz    35        Temuco      pedro.diaz@email.com
# 5           6     Laura Rojas    27   Antofagasta     laura.rojas@email.com
# 6           7    Diego Torres    40      Rancagua    diego.torres@email.com
# 7           8   Sofía Herrera    24  Puerto Montt   sofia.herrera@email.com
# 8           9   Andrés Castro    33       Iquique   andres.castro@email.com
# 9          10    Camila Silva    29         Talca    camila.silva@email.com
